# %%
pip install pandas==2.03
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 1.2 MB/s eta 0:00:09
#    -- ------------------------------------- 0.8/11.0 MB 1.3 MB/s eta 0:00:08
#    -- ------------------------------------- 0.8/11.0 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 1.0/11.0 MB 1.1 MB/s eta 0:00:09
#    ------ --------------------------------- 1.8/11.0 MB 1.5 MB/s eta 0:00:07
#    ------- -------------------------------- 2.1/11.0 MB 1.5 MB/s eta 0:00:06
#    -------- ------------------------------- 2.4/11.0 MB 1.6 MB/s eta 0:00:06
#    ---------- ----------------------------- 2.9/11.0 MB 1.7 MB/s eta 0:00:05
# ...

# %%
pip show langchain
# Out:
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Package(s) not found: langchain

# %%
pip install langchain_openai==0.3.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached langchain_openai-0.3.4-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached tenacity-9.1.2-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# ...
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# ...
#   Using cached httpcore-1.0.9-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#   Using cached jsonpointer-3.0.0-py2.py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...

# %%
pip install langchain==0.3.18
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached langchain-0.3.18-py3-none-any.whl.metadata (7.8 kB)
# ...
#   Using cached langsmith-0.3.45-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# ...
# Using cached langchain-0.3.18-py3-none-any.whl (1.0 MB)
# ...
# Using cached langsmith-0.3.45-py3-none-any.whl (363 kB)
# ...
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.5/2.1 MB 2.1 MB/s eta 0:00:01
#    -------------- ------------------------- 0.8/2.1 MB 2.1 MB/s eta 0:00:01
#    ------------------- -------------------- 1.0/2.1 MB 2.1 MB/s eta 0:00:01
#    ------------------------ --------------- 1.3/2.1 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 1.8/2.1 MB 1.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 1.6 MB/s eta 0:00:00
# ...

# %%
print("test")
# Out:
# test

# %%
pip install numpy==1.26.4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.5 MB ? eta -:--:--
#    - -------------------------------------- 0.5/15.5 MB 2.4 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/15.5 MB 2.4 MB/s eta 0:00:07
#    --- ------------------------------------ 1.3/15.5 MB 2.0 MB/s eta 0:00:07
#    ----- ---------------------------------- 2.1/15.5 MB 2.4 MB/s eta 0:00:06
#    ------ --------------------------------- 2.6/15.5 MB 2.7 MB/s eta 0:00:05
#    -------- ------------------------------- 3.1/15.5 MB 2.8 MB/s eta 0:00:05
#    ---------- ----------------------------- 3.9/15.5 MB 2.6 MB/s eta 0:00:05
#    ---------- ----------------------------- 4.2/15.5 MB 2.6 MB/s eta 0:00:05
#    ------------ --------------------------- 4.7/15.5 MB 2.5 MB/s eta 0:00:05
# ...

# %%
pip install snowflake-connector-python==3.11.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install dash==2.17.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached dash-2.17.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# ...
#   Using cached werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# ...
#   Using cached zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# ...
# Using cached dash-2.17.1-py3-none-any.whl (7.5 MB)
# ...

# %%
pip install dash-ag-grid==2.2.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached dash_ag_grid-2.2.0-py3-none-any.whl.metadata (4.2 kB)
# ...
# Using cached dash_ag_grid-2.2.0-py3-none-any.whl (3.7 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install dash-bootstrap-components==1.4.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached dash_bootstrap_components-1.4.2-py3-none-any.whl.metadata (5.2 kB)
# ...
# Using cached dash_bootstrap_components-1.4.2-py3-none-any.whl (220 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install dash-bootstrap-templates==1.1.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached dash_bootstrap_templates-1.1.1-py3-none-any.whl.metadata (16 kB)
# ...
# Using cached dash_bootstrap_templates-1.1.1-py3-none-any.whl (96 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install dash-core-components==2.0.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install dash-extensions==1.0.3
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached dash_extensions-1.0.3-py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached Flask_Caching-2.0.2-py3-none-any.whl.metadata (2.2 kB)
# ...
#   Using cached dataclass_wizard-0.22.3-py2.py3-none-any.whl.metadata (34 kB)
# ...
#   Using cached jsbeautifier-1.15.4-py3-none-any.whl.metadata (374 bytes)
# ...
#   Using cached more_itertools-9.1.0-py3-none-any.whl.metadata (32 kB)
# ...
#   Using cached cachelib-0.9.0-py3-none-any.whl.metadata (1.9 kB)
# ...
#   Using cached flask-2.3.3-py3-none-any.whl.metadata (3.6 kB)
# ...
#   Using cached editorconfig-0.17.1-py3-none-any.whl.metadata (3.9 kB)
# ...
# Using cached dash_extensions-1.0.3-py3-none-any.whl (1.4 MB)
# Using cached Flask_Caching-2.0.2-py3-none-any.whl (28 kB)
# Using cached dataclass_wizard-0.22.3-py2.py3-none-any.whl (90 kB)
# Using cached jsbeautifier-1.15.4-py3-none-any.whl (94 kB)
# Using cached more_itertools-9.1.0-py3-none-any.whl (54 kB)
# ...

# %%
pip install dash-html-components==2.0.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install dash-iconify==0.1.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached dash_iconify-0.1.2-py3-none-any.whl.metadata (2.2 kB)
# Using cached dash_iconify-0.1.2-py3-none-any.whl (18 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install dash-mantine-components==0.12.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached dash_mantine_components-0.12.1-py3-none-any.whl.metadata (3.4 kB)
# Using cached dash_mantine_components-0.12.1-py3-none-any.whl (500 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install dash-table
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install colorlover
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached colorlover-0.3.0-py3-none-any.whl.metadata (421 bytes)
# Using cached colorlover-0.3.0-py3-none-any.whl (8.9 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install chromadb==0.5.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached chromadb-0.5.0-py3-none-any.whl.metadata (7.3 kB)
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached PyPika-0.48.9.tar.gz (67 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached overrides-7.7.0-py3-none-any.whl.metadata (5.8 kB)
# ...

# %%
pip install cvxpy==1.3.2
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#      ------- -------------------------------- 0.3/1.3 MB ? eta -:--:--
#      ------- -------------------------------- 0.3/1.3 MB ? eta -:--:--
#      --------------- ------------------------ 0.5/1.3 MB 762.0 kB/s eta 0:00:02
#      ---------------------------------------  1.3/1.3 MB 1.6 MB/s eta 0:00:01
#      ---------------------------------------- 1.3/1.3 MB 1.6 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...

# %%
pip install GitPython
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# ...
#   Using cached smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# ...
# Using cached gitdb-4.0.12-py3-none-any.whl (62 kB)
# Using cached smmap-5.0.2-py3-none-any.whl (24 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install gs-quant==1.0.41
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached gs_quant-1.0.41-py3-none-any.whl.metadata (4.3 kB)
# ...
#   Using cached asteval-0.9.23.tar.gz (55 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [31 lines of output]
#       C:\Users\shreya.lingam\AppData\Local\Temp\pip-install-j0142y44\asteval_a523f79e73a34ee49d0ed3fafc069a0e\versioneer.py:421: SyntaxWarning: invalid escape sequence '\s'
#         LONG_VERSION_PY['git'] = '''
#       Traceback (most recent call last):
# ...

# %%
pip install ismember
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached ismember-1.1.0-py3-none-any.whl.metadata (4.8 kB)
# ...
# Using cached ismember-1.1.0-py3-none-any.whl (8.0 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 1.2 MB/s eta 0:00:07
#    -- ------------------------------------- 0.5/8.1 MB 1.2 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/8.1 MB 1.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 1.0/8.1 MB 1.1 MB/s eta 0:00:07
#    ------ --------------------------------- 1.3/8.1 MB 1.1 MB/s eta 0:00:07
#    ------- -------------------------------- 1.6/8.1 MB 1.1 MB/s eta 0:00:06
#    ------- -------------------------------- 1.6/8.1 MB 1.1 MB/s eta 0:00:06
#    --------- ------------------------------ 1.8/8.1 MB 976.9 kB/s eta 0:00:07
#    --------- ------------------------------ 1.8/8.1 MB 976.9 kB/s eta 0:00:07
# ...

# %%
pip install matplotlib-inline
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install Mosek==10.1b4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Ignored the following versions that require a different python version: 10.1.10 Requires-Python <3.12,>=3.7; 10.1.11 Requires-Python <3.12,>=3.7; 10.1.12 Requires-Python <3.12,>=3.7; 10.1.13 Requires-Python <3.12,>=3.7; 10.1.14 Requires-Python <3.12,>=3.7; 10.1.8 Requires-Python <3.12,>=3.7; 10.1.9 Requires-Python <3.12,>=3.7; 10.1b0 Requires-Python <3.12,>=3.7; 10.1b1 Requires-Python <3.12,>=3.7; 10.1b2 Requires-Python <3.12,>=3.7; 10.1b3 Requires-Python <3.12,>=3.7; 10.1b4 Requires-Python <3.12,>=3.7; 10.1b5 Requires-Python <3.12,>=3.7; 10.1b6 Requires-Python <3.12,>=3.7; 10.1b7 Requires-Python <3.12,>=3.7
# ...

# %%
pip install nltk
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached joblib-1.5.2-py3-none-any.whl.metadata (5.6 kB)
# ...
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.5 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.5 MB ? eta -:--:--
#    ------------- -------------------------- 0.5/1.5 MB 989.2 kB/s eta 0:00:01
#    ------------- -------------------------- 0.5/1.5 MB 989.2 kB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 780.2 kB/s eta 0:00:01
#    -------------------- ------------------- 0.8/1.5 MB 780.2 kB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.5 MB 762.8 kB/s eta 0:00:01
#    --------------------------- ------------ 1.0/1.5 MB 762.8 kB/s eta 0:00:01
#    ---------------------------------- ----- 1.3/1.5 MB 706.6 kB/s eta 0:00:01
#    ---------------------------------------- 1.5/1.5 MB 702.6 kB/s eta 0:00:00
# ...

# %%
pip install numba
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/2.7 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/2.7 MB ? eta -:--:--
#    ------- -------------------------------- 0.5/2.7 MB 1.1 MB/s eta 0:00:02
#    ----------- ---------------------------- 0.8/2.7 MB 1.2 MB/s eta 0:00:02
#    --------------- ------------------------ 1.0/2.7 MB 1.4 MB/s eta 0:00:02
#    ------------------- -------------------- 1.3/2.7 MB 1.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 1.6/2.7 MB 1.4 MB/s eta 0:00:01
#    -------------------------- ------------- 1.8/2.7 MB 1.4 MB/s eta 0:00:01
#    ------------------------------ --------- 2.1/2.7 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 1.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 2.4/2.7 MB 1.3 MB/s eta 0:00:01
# ...

# %%
pip install openai==1.41.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached openai-1.41.0-py3-none-any.whl.metadata (22 kB)
# ...
# Using cached openai-1.41.0-py3-none-any.whl (362 kB)
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.109.1
#     Uninstalling openai-1.109.1:
#       Successfully uninstalled openai-1.109.1
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-openai 0.3.4 requires openai<2.0.0,>=1.58.1, but you have openai 1.41.0 which is incompatible.
#
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Using cached openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Using cached et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas==2.03
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas-flavor==0.6.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pandas_flavor-0.6.0-py3-none-any.whl.metadata (6.3 kB)
# ...
# Using cached pandas_flavor-0.6.0-py3-none-any.whl (7.2 kB)
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.4 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.4 MB 2.4 MB/s eta 0:00:01
#    ------------------------------ --------- 1.0/1.4 MB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 1.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install plotly==5.22.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# ...
# Using cached plotly-5.22.0-py3-none-any.whl (16.4 MB)
# ...
#   Attempting uninstall: plotly
#     Found existing installation: plotly 6.5.0
#     Uninstalling plotly-6.5.0:
#       Successfully uninstalled plotly-6.5.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install langchain-openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached openai-1.109.1-py3-none-any.whl.metadata (29 kB)
# ...
# Using cached openai-1.109.1-py3-none-any.whl (948 kB)
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.41.0
#     Uninstalling openai-1.41.0:
#       Successfully uninstalled openai-1.41.0
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.3.1/en_core_web_sm-2.3.1.tar.gz
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/12.0 MB ? eta -:--:--
#       --------------------------------------- 0.3/12.0 MB ? eta -:--:--
#      - -------------------------------------- 0.5/12.0 MB 1.7 MB/s eta 0:00:07
#      -- ------------------------------------- 0.8/12.0 MB 1.9 MB/s eta 0:00:07
#      --- ------------------------------------ 1.0/12.0 MB 1.5 MB/s eta 0:00:08
#      ----- ---------------------------------- 1.6/12.0 MB 1.5 MB/s eta 0:00:07
#      ------ --------------------------------- 1.8/12.0 MB 1.5 MB/s eta 0:00:07
#      ------ --------------------------------- 2.1/12.0 MB 1.4 MB/s eta 0:00:08
#      ------- -------------------------------- 2.4/12.0 MB 1.5 MB/s eta 0:00:07
#      --------- ------------------------------ 2.9/12.0 MB 1.5 MB/s eta 0:00:06
#      ---------- ----------------------------- 3.1/12.0 MB 1.5 MB/s eta 0:00:06
# ...

# %%
pip install pretty-html-table
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pretty_html_table-0.9.16-py3-none-any.whl.metadata (8.5 kB)
# ...
# Using cached pretty_html_table-0.9.16-py3-none-any.whl (6.8 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyaml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyarrow
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/28.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/28.0 MB ? eta -:--:--
#     --------------------------------------- 0.5/28.0 MB 1.1 MB/s eta 0:00:25
#     --------------------------------------- 0.5/28.0 MB 1.1 MB/s eta 0:00:25
#    - -------------------------------------- 0.8/28.0 MB 1.0 MB/s eta 0:00:27
#    - -------------------------------------- 1.0/28.0 MB 1.1 MB/s eta 0:00:26
#    - -------------------------------------- 1.3/28.0 MB 1.0 MB/s eta 0:00:26
#    -- ------------------------------------- 1.6/28.0 MB 1.1 MB/s eta 0:00:25
#    -- ------------------------------------- 1.8/28.0 MB 1.1 MB/s eta 0:00:25
#    -- ------------------------------------- 2.1/28.0 MB 1.1 MB/s eta 0:00:25
#    --- ------------------------------------ 2.4/28.0 MB 1.1 MB/s eta 0:00:23
# ...

# %%
pip install pycountry==23.12.11
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pycountry-23.12.11-py3-none-any.whl.metadata (12 kB)
# Using cached pycountry-23.12.11-py3-none-any.whl (6.2 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyjanitor
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached natsort-8.4.0-py3-none-any.whl.metadata (21 kB)
# ...
#   Using cached multipledispatch-1.0.0-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
# Using cached multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Using cached natsort-8.4.0-py3-none-any.whl (38 kB)
# Using cached scipy-1.16.3-cp312-cp312-win_amd64.whl (38.6 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pyLDAvis
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pyLDAvis-3.4.1-py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached funcy-2.0-py2.py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# ...
# Using cached pyLDAvis-3.4.1-py3-none-any.whl (2.6 MB)
# ...
#    ---------------------------------------- 0.0/8.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.7 MB 1.3 MB/s eta 0:00:07
#    --- ------------------------------------ 0.8/8.7 MB 1.6 MB/s eta 0:00:05
#    ------ --------------------------------- 1.3/8.7 MB 1.9 MB/s eta 0:00:04
#    -------- ------------------------------- 1.8/8.7 MB 1.9 MB/s eta 0:00:04
#    --------- ------------------------------ 2.1/8.7 MB 1.8 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.4/8.7 MB 1.8 MB/s eta 0:00:04
# ...

# %%
pip install pyodbc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pywin32 openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.1.1 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import snowflake_connector_config as config

# %%
pip install PyYAML
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install ridgeplot
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.6 MB 2.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 1.3/9.6 MB 2.2 MB/s eta 0:00:04
#    ------- -------------------------------- 1.8/9.6 MB 2.6 MB/s eta 0:00:04
#    -------- ------------------------------- 2.1/9.6 MB 2.4 MB/s eta 0:00:04
#    ---------- ----------------------------- 2.6/9.6 MB 2.3 MB/s eta 0:00:04
#    ------------- -------------------------- 3.1/9.6 MB 2.4 MB/s eta 0:00:03
#    -------------- ------------------------- 3.4/9.6 MB 2.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 3.9/9.6 MB 2.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 4.2/9.6 MB 2.2 MB/s eta 0:00:03
# ...

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install scipy==1.11.1
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/56.0 MB ? eta -:--:--
#      ---------------------------------------- 0.3/56.0 MB ? eta -:--:--
#      ---------------------------------------- 0.5/56.0 MB 1.1 MB/s eta 0:00:50
#       --------------------------------------- 0.8/56.0 MB 1.3 MB/s eta 0:00:43
#       --------------------------------------- 1.3/56.0 MB 1.5 MB/s eta 0:00:36
#      - -------------------------------------- 1.6/56.0 MB 1.4 MB/s eta 0:00:40
#      - -------------------------------------- 1.6/56.0 MB 1.4 MB/s eta 0:00:40
#      - -------------------------------------- 1.8/56.0 MB 1.3 MB/s eta 0:00:41
#      - -------------------------------------- 2.1/56.0 MB 1.3 MB/s eta 0:00:41
#      - -------------------------------------- 2.4/56.0 MB 1.3 MB/s eta 0:00:42
#      - -------------------------------------- 2.6/56.0 MB 1.3 MB/s eta 0:00:41
# ...

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# ...
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install sentence-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached huggingface_hub-1.1.6-py3-none-any.whl.metadata (13 kB)
# ...
#   Using cached fsspec-2025.10.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached hf_xet-1.2.0-cp37-abi3-win_amd64.whl.metadata (5.0 kB)
# ...
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# ...
#   Using cached typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# ...
#   Using cached tokenizers-0.22.1-cp39-abi3-win_amd64.whl.metadata (6.9 kB)
# ...
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# ...
#    ---------------------------------------- 0.0/110.9 MB ? eta -:--:--
#    ---------------------------------------- 0.5/110.9 MB 2.4 MB/s eta 0:00:47
#    ---------------------------------------- 0.8/110.9 MB 2.0 MB/s eta 0:00:56
#    ---------------------------------------- 1.3/110.9 MB 1.8 MB/s eta 0:01:03
# ...

# %%
pip install shap
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached numpy-2.3.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# ...
#   Using cached slicer-0.0.8-py3-none-any.whl.metadata (4.0 kB)
# ...
#    ---------------------------------------- 0.0/549.3 kB ? eta -:--:--
#    ---------------------------------------- 0.0/549.3 kB ? eta -:--:--
#    -------------------------------------- - 524.3/549.3 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 549.3/549.3 kB 1.3 MB/s eta 0:00:00
# Using cached slicer-0.0.8-py3-none-any.whl (15 kB)
# Using cached numpy-2.3.5-cp312-cp312-win_amd64.whl (12.8 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install snowflake-connector-python==3.11.0
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install spacy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached murmurhash-1.0.15-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# ...
#   Using cached cymem-2.0.13-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# ...
#   Using cached preshed-3.0.12-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# ...
#   Using cached typer_slim-0.20.0-py3-none-any.whl.metadata (16 kB)
# ...
#    ---------------------------------------- 0.0/14.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.2 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.2 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.2 MB 882.6 kB/s eta 0:00:16
#    -- ------------------------------------- 0.8/14.2 MB 907.1 kB/s eta 0:00:15
#    -- ------------------------------------- 0.8/14.2 MB 907.1 kB/s eta 0:00:15
#    -- ------------------------------------- 1.0/14.2 MB 838.4 kB/s eta 0:00:16
#    --- ------------------------------------ 1.3/14.2 MB 860.2 kB/s eta 0:00:16
# ...

# %%
pip install sydney-py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached sydney_py-0.23.1-py3-none-any.whl.metadata (12 kB)
# ...
# Using cached sydney_py-0.23.1-py3-none-any.whl (15 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install xbbg
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pluggy-1.6.0-py3-none-any.whl.metadata (4.8 kB)
# ...
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ---------------------------- ----------- 0.8/1.1 MB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 1.0/1.1 MB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 1.1/1.1 MB 1.3 MB/s eta 0:00:00
# ...
# Using cached pluggy-1.6.0-py3-none-any.whl (20 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.3/72.0 MB ? eta -:--:--
#    ---------------------------------------- 0.5/72.0 MB 1.2 MB/s eta 0:01:00
#    ---------------------------------------- 0.8/72.0 MB 1.3 MB/s eta 0:00:56
#     --------------------------------------- 1.0/72.0 MB 1.4 MB/s eta 0:00:53
#     --------------------------------------- 1.3/72.0 MB 1.4 MB/s eta 0:00:50
#     --------------------------------------- 1.6/72.0 MB 1.4 MB/s eta 0:00:49
#    - -------------------------------------- 1.8/72.0 MB 1.4 MB/s eta 0:00:50
#    - -------------------------------------- 2.4/72.0 MB 1.4 MB/s eta 0:00:49
#    - -------------------------------------- 2.6/72.0 MB 1.4 MB/s eta 0:00:49
#    - -------------------------------------- 2.9/72.0 MB 1.5 MB/s eta 0:00:48
# ...

# %%
pip install langchain
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install textblob
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached textblob-0.19.0-py3-none-any.whl.metadata (4.4 kB)
# ...
# Using cached textblob-0.19.0-py3-none-any.whl (624 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
conda install conda-forge::blpapi
# Out:
#   Cell In[61], line 1
#     python -m pip install --index-url=https://blpapi.bloomberg.com/repository/releases/python/simple/ blpapi
#               ^
# SyntaxError: invalid syntax

# %%
pip install spacy==2.3.5
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached spacy-2.3.5.tar.gz (5.8 MB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   × pip subprocess to install build dependencies did not run successfully.
#   │ exit code: 1
#   ╰─> [49 lines of output]
# ...
#         Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# ...
#         Using cached cython-3.2.2-cp312-cp312-win_amd64.whl.metadata (5.1 kB)
# ...
#         Using cached cymem-2.0.13-cp312-cp312-win_amd64.whl.metadata (9.9 kB)
# ...
#         Using cached preshed-3.0.12-cp312-cp312-win_amd64.whl.metadata (2.6 kB)
# ...
#         Using cached murmurhash-1.0.15-cp312-cp312-win_amd64.whl.metadata (2.3 kB)
# ...
#         Using cached thinc-7.4.6.tar.gz (1.3 MB)
#         Installing build dependencies: started
# ...

# %%
pip install PyPDF2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sendgrid
# Out:
# ...
#   Using cached cffi-2.0.0-cp311-cp311-win_amd64.whl.metadata (2.6 kB)
# ...
#    ---------------------------------------- 0.0/3.5 MB ? eta -:--:--
#    ----------- ---------------------------- 1.0/3.5 MB 7.1 MB/s eta 0:00:01
#    ---------------------------------------- 3.5/3.5 MB 9.9 MB/s eta 0:00:00
# Using cached cffi-2.0.0-cp311-cp311-win_amd64.whl (182 kB)
# ...
#
#   Attempting uninstall: cffi
#
#     Found existing installation: cffi 1.17.1
#
#     Uninstalling cffi-1.17.1:
#
#    ---------------------------------------- 0/2 [cffi]
#       Successfully uninstalled cffi-1.17.1
#    ---------------------------------------- 0/2 [cffi]
#   Attempting uninstall: cryptography
#    ---------------------------------------- 0/2 [cffi]
#     Found existing installation: cryptography 42.0.8
#    ---------------------------------------- 0/2 [cffi]
#     Uninstalling cryptography-42.0.8:
#    ---------------------------------------- 0/2 [cffi]
#       Successfully uninstalled cryptography-42.0.8
# ...

# %%
pip install pdfplumber
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/6.6 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.6 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.6 MB 1.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 0.8/6.6 MB 1.5 MB/s eta 0:00:04
#    ------- -------------------------------- 1.3/6.6 MB 1.4 MB/s eta 0:00:04
#    --------- ------------------------------ 1.6/6.6 MB 1.4 MB/s eta 0:00:04
#    ----------- ---------------------------- 1.8/6.6 MB 1.5 MB/s eta 0:00:04
#    -------------- ------------------------- 2.4/6.6 MB 1.5 MB/s eta 0:00:03
#    --------------- ------------------------ 2.6/6.6 MB 1.5 MB/s eta 0:00:03
#    --------------- ------------------------ 2.6/6.6 MB 1.5 MB/s eta 0:00:03
#    ----------------- ---------------------- 2.9/6.6 MB 1.4 MB/s eta 0:00:03
# ...

# %%
pip install --upgrade "langchain-core>=0.3.81,<1.0.0"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
